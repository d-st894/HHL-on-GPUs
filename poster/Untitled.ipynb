# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
genv=[1.9,2.6,2.9,3.4,3.5]
gena=[3.8,4.6,5.1,6.7,7.2]
qgen=[8,10,10,10,12]
sgen=[4,8,16,16,32]

diagrv=[2.3,1.7,1.5,1.8,1.8]
diagra=[3.5,3.4,3.4,4.8,5.7]
qdiagr=[8,8,10,10,12]
sdiagr=[4,8,8,16,16]

diagv=[2.9,2.0,3.3,3.6,3.6,3.7]
diagaa=[3.6,3.2,4.2,5.1,5.4,6.5]
qdiag=[8,8,10,10,12,12]
sdiag=[4,8,8,16,16,32]

# %%
[fig,ax]=plt.subplots()
ax.plot(sdiag,diagv,label='V100')
ax.plot(sdiag,diaga,label='A100')
ax.grid()
#ax.set_title('GPU Speedup for Diagonal Matrices',fontsize=16)
ax.set_xlabel('System Size',fontsize=14)
ax.set_ylabel('Percentage Speedup',fontsize=14)
ax.legend(prop={'size':12})
plt.savefig('diag.png',bbox_inches='tight')
plt.show()

# %%
[fig,ax]=plt.subplots()
ax.plot(sdiagr,diagrv,label='V100')
ax.plot(sdiagr,diagra,label='A100')
ax.grid()
#ax.set_title('GPU Speedup for Diagonal Matrices',fontsize=16)
ax.set_xlabel('System Size',fontsize=14)
ax.set_ylabel('Percentage Speedup',fontsize=14)
ax.legend(prop={'size':12})
plt.savefig('diagr.png',bbox_inches='tight')
plt.show()

# %%
[fig,ax]=plt.subplots()
ax.plot(sgen,genv,label='V100')
ax.plot(sgen,gena,label='A100')
ax.grid()
#ax.set_title('GPU Speedup for Diagonal Matrices',fontsize=16)
ax.set_xlabel('System Size',fontsize=14)
ax.set_ylabel('Percentage Speedup',fontsize=14)
ax.legend(prop={'size':12})
plt.savefig('gen.png',bbox_inches='tight')
plt.show()
